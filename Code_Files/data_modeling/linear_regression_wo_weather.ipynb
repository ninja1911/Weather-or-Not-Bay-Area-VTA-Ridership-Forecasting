# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Import packages

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    make_scorer,
)
import pandas as pd
import numpy as np
import pickle
import os

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"

# %% [markdown]
# ## Load the dataframe

# %%
train_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "train_wo_weather.csv"))
test_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "test_wo_weather.csv"))

# %% [markdown]
# ## Split into X and y

# %%
train_X = train_df[[x for x in train_df.columns if x not in ["On", "Off"]]]
train_y = train_df["On"]
test_X = test_df[[x for x in test_df.columns if x not in ["On", "Off"]]]
test_y = test_df["On"]

# %% [markdown]
# ## Train the Linear Regression Model

# %%
std = StandardScaler()
pca = PCA(random_state=42)
reg = ElasticNet(random_state=42)
lr = Pipeline(
    [("standardization", std), ("decomposition", pca), ("regression", reg)],
    verbose=True,
)
lr = lr.fit(X=train_X, y=train_y)
# Out:
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.5s

# %%
train_y_pred = np.floor(lr.predict(train_X)).astype(int)
test_y_pred = np.floor(lr.predict(test_X)).astype(int)

# %% [markdown]
# ## Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 45.77232239377747
# train mae: 17.472760533321363
# train r2 score: 0.14946657276625952

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 43.452505039230516
# test mae: 17.146198357110986
# test r2 score: 0.19065033970178002

# %% [markdown]
# ## Export Model

# %%
pickle.dump(lr, open(os.path.join(MODELS_FOLDER, "base_elastic_net_wo_weather.pkl"), "wb"))

# %% [markdown]
# ## Hyperparameter Tuning with GridSearchCV

# %% [markdown]
# ### Declare base model and parameters

# %%
std = StandardScaler()
pca = PCA(random_state=42)
reg = ElasticNet(random_state=42)
base_lr = Pipeline(
    [("standardization", std), ("decomposition", pca), ("regression", reg)],
    verbose=True,
)
param_grid = {
    "decomposition__n_components": [5, 6, 7],
    "regression__alpha": [0.5, 1.0],
    "regression__l1_ratio": [0.3, 0.5, 0.7],
}

# %% [markdown]
# ### Declare the scorer and grid search

# %%
scorer = make_scorer(mean_squared_error, greater_is_better=False)
grid_search = GridSearchCV(base_lr, param_grid, scoring=scorer, n_jobs=-1, verbose=2, cv=5)

# %% [markdown]
# ### Train the models

# %%
grid_search.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  18.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.7s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  21.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  19.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  19.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  20.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  21.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  21.6s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  23.5s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  24.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  22.1s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  24.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  22.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  22.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  22.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  25.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  25.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  26.1s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  26.1s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  26.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  26.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.3s[Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.1s
#
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s[Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
#
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   9.5s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  16.5s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  14.8s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  14.9s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  15.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [CV] END decomposition__n_components=5, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  15.1s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  14.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  12.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  12.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  12.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  15.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  16.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  16.9s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  16.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.6s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  13.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  11.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.8s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  15.1s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  15.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  14.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   9.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  14.0s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  14.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  13.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  10.1s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  13.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   3.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  14.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.1s
# [CV] END decomposition__n_components=5, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  14.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   3.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   3.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   6.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   6.1s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   6.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   6.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   6.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.7s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   6.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   3.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   6.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   4.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [CV] END decomposition__n_components=6, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.5s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   1.9s[Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
#
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   4.4s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   5.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   5.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   5.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   5.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [CV] END decomposition__n_components=6, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   5.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   5.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   5.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   5.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=   5.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.8s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   4.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   5.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.2s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   4.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.4s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=   5.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.1s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   4.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   5.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   4.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.0s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.9s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   5.0s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=   4.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   4.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   1.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.5s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardization', StandardScaler()),
#                                        ('decomposition', PCA(random_state=42)),
#                                        ('regression',
#                                         ElasticNet(random_state=42))],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'decomposition__n_components': [5, 6, 7],
#                          'regression__alpha': [0.5, 1.0],
#                          'regression__l1_ratio': [0.3, 0.5, 0.7]},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       23.712591      1.908770         0.625731        0.175195
# 1       24.824353      0.989462         0.518780        0.112499
# 2       14.459359      0.790159         0.906243        0.370935
# 3       15.418422      0.938389         0.662170        0.174998
# 4       14.136980      0.583181         0.492372        0.298041
# 5       13.382615      0.331518         0.638806        0.178176
# 6        5.748995      0.078564         0.364680        0.082636
# 7        5.381383      0.280719         0.398772        0.067381
# 8        4.695368      0.159486         0.365158        0.079200
# 9        4.787373      0.364542         0.368082        0.108513
# 10       4.442242      0.337830         0.307852        0.104445
# 11       4.922951      0.408868         0.438871        0.148724
# 12       4.961957      0.239836         0.336893        0.052309
# 13       4.850106      0.171691         0.311676        0.054734
# 14       4.711722      0.207521         0.400778        0.080431
# 15       4.628690      0.241557         0.252975        0.034150
# 16       4.537786      0.164557         0.236807        0.035405
# 17       4.247494      0.216860         0.167569        0.029864
#
#    param_decomposition__n_components param_regression__alpha  \
# 0                                  5                     0.5
# 1                                  5                     0.5
# 2                                  5                     0.5
# 3                                  5                     1.0
# 4                                  5                     1.0
# 5                                  5                     1.0
# 6                                  6                     0.5
# 7                                  6                     0.5
# 8                                  6                     0.5
# 9                                  6                     1.0
# 10                                 6                     1.0
# 11                                 6                     1.0
# 12                                 7                     0.5
# 13                                 7                     0.5
# 14                                 7                     0.5
# 15                                 7                     1.0
# 16                                 7                     1.0
# 17                                 7                     1.0
#
#    param_regression__l1_ratio  \
# 0                         0.3
# 1                         0.5
# 2                         0.7
# 3                         0.3
# 4                         0.5
# 5                         0.7
# 6                         0.3
# 7                         0.5
# 8                         0.7
# 9                         0.3
# 10                        0.5
# 11                        0.7
# 12                        0.3
# 13                        0.5
# 14                        0.7
# 15                        0.3
# 16                        0.5
# 17                        0.7
#
#                                                params  split0_test_score  \
# 0   {'decomposition__n_components': 5, 'regression...       -2204.153736
# 1   {'decomposition__n_components': 5, 'regression...       -2197.765966
# 2   {'decomposition__n_components': 5, 'regression...       -2192.136673
# 3   {'decomposition__n_components': 5, 'regression...       -2233.734442
# 4   {'decomposition__n_components': 5, 'regression...       -2220.110595
# 5   {'decomposition__n_components': 5, 'regression...       -2206.285414
# 6   {'decomposition__n_components': 6, 'regression...       -2095.497934
# 7   {'decomposition__n_components': 6, 'regression...       -2085.238296
# 8   {'decomposition__n_components': 6, 'regression...       -2075.951391
# 9   {'decomposition__n_components': 6, 'regression...       -2140.917930
# 10  {'decomposition__n_components': 6, 'regression...       -2120.177657
# 11  {'decomposition__n_components': 6, 'regression...       -2098.386813
# 12  {'decomposition__n_components': 7, 'regression...       -2095.170408
# 13  {'decomposition__n_components': 7, 'regression...       -2084.982409
# 14  {'decomposition__n_components': 7, 'regression...       -2075.809522
# 15  {'decomposition__n_components': 7, 'regression...       -2140.808636
# 16  {'decomposition__n_components': 7, 'regression...       -2120.177657
# 17  {'decomposition__n_components': 7, 'regression...       -2098.386813
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0        -2183.548084       -2251.169061       -2097.704925
# 1        -2177.382013       -2244.576342       -2091.633526
# 2        -2172.014576       -2238.707531       -2086.385260
# 3        -2212.496053       -2281.458957       -2126.295011
# 4        -2199.141472       -2267.569781       -2113.024110
# 5        -2185.669647       -2253.394572       -2099.679764
# 6        -2075.652072       -2140.855563       -1991.448421
# 7        -2065.722899       -2130.245751       -1981.844515
# 8        -2056.836265       -2120.540182       -1973.372601
# 9        -2120.164413       -2187.413540       -2034.971813
# 10       -2099.803962       -2166.247785       -2014.913347
# 11       -2078.530396       -2143.883019       -1994.095148
# 12       -2075.340771       -2140.564404       -1991.124481
# 13       -2065.474844       -2130.010526       -1981.590767
# 14       -2056.689881       -2120.396173       -1973.231793
# 15       -2120.055596       -2187.309087       -2034.864558
# 16       -2099.803962       -2166.247785       -2014.913347
# 17       -2078.530396       -2143.883019       -1994.095148
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0        -2159.518929     -2179.218947       50.695030               15
# 1        -2153.399151     -2172.951400       50.518140               14
# 2        -2148.078133     -2167.464435       50.308376               13
# 3        -2188.180627     -2208.433018       51.276251               18
# 4        -2174.901295     -2194.949450       51.064779               17
# 5        -2161.514581     -2181.308796       50.782511               16
# 6        -2052.460594     -2071.182917       49.342854                6
# 7        -2042.627597     -2061.135812       49.005752                4
# 8        -2033.846777     -2052.109443       48.593338                2
# 9        -2096.511270     -2115.995793       50.365696               12
# 10       -2076.285422     -2095.485635       49.992334                9
# 11       -2055.175086     -2074.014092       49.473304                7
# 12       -2052.155909     -2070.871195       49.350527                5
# 13       -2042.385142     -2060.888738       49.010020                3
# 14       -2033.705140     -2051.966502       48.592286                1
# 15       -2096.406021     -2115.888780       50.366108               11
# 16       -2076.285422     -2095.485635       49.992334                9
# 17       -2055.175086     -2074.014092       49.473304                7

# %%
print(grid_search.best_params_)
# Out:
# {'decomposition__n_components': 7, 'regression__alpha': 0.5, 'regression__l1_ratio': 0.7}

# %% [markdown]
# ### Extract the best model

# %%
best_lr = grid_search.best_estimator_

# %%
train_y_pred = np.floor(best_lr.predict(train_X)).astype(int)
test_y_pred = np.floor(best_lr.predict(test_X)).astype(int)

# %% [markdown]
# ### Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 45.30223681789324
# train mae: 17.412751000727656
# train r2 score: 0.1668469618219387

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 42.778246439202
# test mae: 17.029904762859736
# test r2 score: 0.21557304699659363

# %% [markdown]
# ### Export Models

# %%
pickle.dump(best_lr, open(os.path.join(MODELS_FOLDER, "tuned_elastic_net_wo_weather.pkl"), "wb"))
