# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Import packages

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    make_scorer,
)
import pandas as pd
import numpy as np
import pickle
import os

# %%
CLEAN_DATA_FOLDER = "clean_data"
MODELS_FOLDER = "models"

# %% [markdown]
# ## Load the dataframe

# %%
train_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "train.csv"))
test_df = pd.read_csv(os.path.join(CLEAN_DATA_FOLDER, "test.csv"))

# %% [markdown]
# ## Split into X and y

# %%
train_X = train_df[[x for x in train_df.columns if x not in ["On", "Off"]]]
train_y = train_df["On"]
test_X = test_df[[x for x in test_df.columns if x not in ["On", "Off"]]]
test_y = test_df["On"]

# %% [markdown]
# ## Train the Linear Regression Model

# %%
std = StandardScaler()
pca = PCA(random_state=42)
reg = ElasticNet(random_state=42)
lr = Pipeline(
    [("standardization", std), ("decomposition", pca), ("regression", reg)],
    verbose=True,
)
lr = lr.fit(X=train_X, y=train_y)
# Out:
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   0.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.7s

# %%
train_y_pred = np.floor(lr.predict(train_X)).astype(int)
test_y_pred = np.floor(lr.predict(test_X)).astype(int)

# %% [markdown]
# ## Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 45.784972877057896
# train mae: 17.482477732277953
# train r2 score: 0.14899636958639972

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 43.47254827709856
# test mae: 17.16333416654789
# test r2 score: 0.18990351375539216

# %% [markdown]
# ## Export Model

# %%
pickle.dump(lr, open(os.path.join(MODELS_FOLDER, "base_elastic_net.pkl"), "wb"))

# %%
del lr

# %% [markdown]
# ## Hyperparameter Tuning with GridSearchCV

# %% [markdown]
# ### Declare base model and parameters

# %%
std = StandardScaler()
pca = PCA(random_state=42)
reg = ElasticNet(random_state=42)
base_lr = Pipeline(
    [("standardization", std), ("decomposition", pca), ("regression", reg)],
    verbose=True,
)
param_grid = {
    "decomposition__n_components": [7, 8, 9],
    "regression__alpha": [0.5, 1.0],
    "regression__l1_ratio": [0.3, 0.5, 0.7],
}

# %% [markdown]
# ### Declare the scorer and grid search

# %%
scorer = make_scorer(mean_squared_error, greater_is_better=False)
grid_search = GridSearchCV(base_lr, param_grid, scoring=scorer, n_jobs=-1, verbose=2, cv=5)

# %% [markdown]
# ### Train the models

# %%
grid_search.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  45.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  46.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  47.5s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  51.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  52.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  49.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  50.0s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  54.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  51.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  52.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  53.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  57.0s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  56.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  53.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  53.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.4s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  58.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.7s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  59.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time= 1.0min
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.5; total time= 1.0min
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.3; total time= 1.0min
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   4.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   6.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  40.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  42.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  42.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  50.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  49.4s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  50.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  39.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  37.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  37.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  37.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  39.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  46.1s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  49.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  42.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  41.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  47.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  47.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  50.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.3s
# [CV] END decomposition__n_components=7, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  53.5s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  52.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   4.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   5.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  36.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  37.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  45.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  45.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  41.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  48.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  36.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  39.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  46.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  41.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  40.9s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  49.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  38.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  50.7s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  50.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  39.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=  39.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  48.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  50.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [CV] END decomposition__n_components=7, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  49.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.6s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  13.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.7s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  12.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  11.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   3.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.3s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  11.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.3s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  11.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  11.0s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  11.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.0s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  12.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.3s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  12.5s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  13.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.7s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  10.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.4s
# [CV] END decomposition__n_components=8, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.7s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  11.8s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  11.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.3; total time=   9.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.4s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  11.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.7s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  11.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  11.4s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.1s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.9s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  11.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  10.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.3s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  10.3s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  12.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.6s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  11.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.2s
# [CV] END decomposition__n_components=8, regression__alpha=1.0, regression__l1_ratio=0.7; total time=  11.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  11.5s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.4s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  10.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  11.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.6s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  10.7s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.3; total time=  10.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.0s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  10.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  10.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.0s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.5; total time=   9.5s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  11.5s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.9s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.5; total time=  10.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.8s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  10.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  10.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.9s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   6.2s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.1s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.0s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.3s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.0s
# [CV] END decomposition__n_components=9, regression__alpha=0.5, regression__l1_ratio=0.7; total time=  11.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.0s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  10.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.3s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.7s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  10.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.6s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  10.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.5s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  11.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.4s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   2.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.6s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.9s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.3; total time=  12.1s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.7s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.0s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.8s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  12.3s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.4s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   2.1s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   5.7s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  11.8s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.2s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.2s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.4s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   9.9s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.5; total time=  10.8s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.7s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.0s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   4.8s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   9.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.1s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   9.3s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   1.2s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   8.6s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   3.8s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.9s
# [CV] END decomposition__n_components=9, regression__alpha=1.0, regression__l1_ratio=0.7; total time=   7.9s
# [Pipeline] ... (step 1 of 3) Processing standardization, total=   1.4s
# [Pipeline] ..... (step 2 of 3) Processing decomposition, total=   2.5s
# [Pipeline] ........ (step 3 of 3) Processing regression, total=   0.7s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardization', StandardScaler()),
#                                        ('decomposition', PCA(random_state=42)),
#                                        ('regression',
#                                         ElasticNet(random_state=42))],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'decomposition__n_components': [7, 8, 9],
#                          'regression__alpha': [0.5, 1.0],
#                          'regression__l1_ratio': [0.3, 0.5, 0.7]},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False, response_method='predict'),
#              verbose=2)

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       55.253004      3.250714         1.250892        0.310408
# 1       56.654857      2.743366         1.204062        0.196340
# 2       49.678724      1.369773         1.027392        0.143390
# 3       47.569263      2.133452         1.193236        0.140659
# 4       46.828394      2.354116         0.798564        0.173810
# 5       48.218465      1.462227         0.929625        0.115088
# 6       11.386129      0.790301         0.791549        0.119821
# 7       11.295661      0.778857         0.881678        0.207775
# 8       10.788408      0.535006         0.659726        0.137932
# 9       10.278630      0.643656         0.975826        0.055908
# 10      10.162250      0.660043         0.743156        0.089278
# 11      10.612577      0.647352         0.639958        0.121021
# 12      10.234696      0.326400         0.854692        0.147656
# 13       9.764934      0.666279         0.716208        0.044223
# 14      10.106792      0.129939         0.872371        0.110285
# 15      10.360096      0.668256         0.845973        0.183699
# 16      10.634831      0.583040         0.509284        0.227805
# 17       8.707162      0.671791         0.284557        0.063909
#
#    param_decomposition__n_components param_regression__alpha  \
# 0                                  7                     0.5
# 1                                  7                     0.5
# 2                                  7                     0.5
# 3                                  7                     1.0
# 4                                  7                     1.0
# 5                                  7                     1.0
# 6                                  8                     0.5
# 7                                  8                     0.5
# 8                                  8                     0.5
# 9                                  8                     1.0
# 10                                 8                     1.0
# 11                                 8                     1.0
# 12                                 9                     0.5
# 13                                 9                     0.5
# 14                                 9                     0.5
# 15                                 9                     1.0
# 16                                 9                     1.0
# 17                                 9                     1.0
#
#    param_regression__l1_ratio  \
# 0                         0.3
# 1                         0.5
# 2                         0.7
# 3                         0.3
# 4                         0.5
# 5                         0.7
# 6                         0.3
# 7                         0.5
# 8                         0.7
# 9                         0.3
# 10                        0.5
# 11                        0.7
# 12                        0.3
# 13                        0.5
# 14                        0.7
# 15                        0.3
# 16                        0.5
# 17                        0.7
#
#                                                params  split0_test_score  \
# 0   {'decomposition__n_components': 7, 'regression...       -2201.405945
# 1   {'decomposition__n_components': 7, 'regression...       -2195.009822
# 2   {'decomposition__n_components': 7, 'regression...       -2189.377866
# 3   {'decomposition__n_components': 7, 'regression...       -2231.590384
# 4   {'decomposition__n_components': 7, 'regression...       -2218.069202
# 5   {'decomposition__n_components': 7, 'regression...       -2204.376265
# 6   {'decomposition__n_components': 8, 'regression...       -2095.421613
# 7   {'decomposition__n_components': 8, 'regression...       -2085.260119
# 8   {'decomposition__n_components': 8, 'regression...       -2076.073105
# 9   {'decomposition__n_components': 8, 'regression...       -2141.072281
# 10  {'decomposition__n_components': 8, 'regression...       -2120.630168
# 11  {'decomposition__n_components': 8, 'regression...       -2099.189601
# 12  {'decomposition__n_components': 9, 'regression...       -2094.981514
# 13  {'decomposition__n_components': 9, 'regression...       -2084.879325
# 14  {'decomposition__n_components': 9, 'regression...       -2075.782746
# 15  {'decomposition__n_components': 9, 'regression...       -2140.880447
# 16  {'decomposition__n_components': 9, 'regression...       -2120.622770
# 17  {'decomposition__n_components': 9, 'regression...       -2099.189601
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0        -2180.861013       -2248.750130       -2095.560883
# 1        -2174.676070       -2242.170508       -2089.513854
# 2        -2169.298154       -2236.329829       -2084.308202
# 3        -2210.367866       -2279.571329       -2124.611300
# 4        -2197.087489       -2265.807441       -2111.474489
# 5        -2183.676262       -2251.750015       -2098.227393
# 6        -2075.512644       -2140.768976       -1991.359108
# 7        -2065.656089       -2130.254465       -1981.844626
# 8        -2056.842716       -2120.651628       -1973.470128
# 9        -2120.235275       -2187.532668       -2035.082818
# 10       -2100.124618       -2166.649138       -2015.295456
# 11       -2079.102102       -2144.570445       -1994.718660
# 12       -2075.082616       -2140.372614       -1990.905652
# 13       -2065.282332       -2129.905030       -1981.453133
# 14       -2056.555833       -2120.375157       -1973.173286
# 15       -2120.047645       -2187.352132       -2034.887287
# 16       -2100.115937       -2166.628187       -2015.290687
# 17       -2079.102102       -2144.570445       -1994.718660
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0        -2156.998694     -2176.715333       50.577892               15
# 1        -2150.847650     -2170.443581       50.397991               14
# 2        -2145.499465     -2164.962703       50.183920               13
# 3        -2186.151914     -2206.458558       51.193168               18
# 4        -2172.917080     -2193.071140       50.981964               17
# 5        -2159.555821     -2179.517151       50.713588               16
# 6        -2052.329483     -2071.078365       49.347175                6
# 7        -2042.542618     -2061.111584       49.015506                4
# 8        -2033.801373     -2052.167790       48.608646                2
# 9        -2096.560996     -2116.096808       50.376379               12
# 10       -2076.538296     -2095.847535       50.013645               10
# 11       -2055.620189     -2074.640199       49.521782                7
# 12       -2051.908078     -2070.650095       49.362606                5
# 13       -2042.175628     -2060.739090       49.026899                3
# 14       -2033.518290     -2051.881062       48.614176                1
# 15       -2096.375478     -2115.908598       50.380351               11
# 16       -2076.527434     -2095.837003       50.009207                9
# 17       -2055.620189     -2074.640199       49.521782                7

# %%
print(grid_search.best_params_)
# Out:
# {'decomposition__n_components': 9, 'regression__alpha': 0.5, 'regression__l1_ratio': 0.7}

# %% [markdown]
# ### Extract the best model

# %%
best_lr = grid_search.best_estimator_

# %%
train_y_pred = np.floor(best_lr.predict(train_X)).astype(int)
test_y_pred = np.floor(best_lr.predict(test_X)).astype(int)

# %% [markdown]
# ### Report Train and Test results

# %%
print("train rmse:", root_mean_squared_error(train_y, train_y_pred))
print("train mae:", mean_absolute_error(train_y, train_y_pred))
print("train r2 score:", r2_score(train_y, train_y_pred))
# Out:
# train rmse: 45.30069133139723
# train mae: 17.420681697259756
# train r2 score: 0.1669038069093497

# %%
print("test rmse:", root_mean_squared_error(test_y, test_y_pred))
print("test mae:", mean_absolute_error(test_y, test_y_pred))
print("test r2 score:", r2_score(test_y, test_y_pred))
# Out:
# test rmse: 42.78110897101234
# test mae: 17.040605243235383
# test r2 score: 0.21546806269169627

# %% [markdown]
# ### Export Models

# %%
pickle.dump(best_lr, open(os.path.join(MODELS_FOLDER, "tuned_elastic_net.pkl"), "wb"))
